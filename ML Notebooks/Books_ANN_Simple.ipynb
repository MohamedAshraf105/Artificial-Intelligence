# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
raw_data = pd.read_csv("booksdata.csv")

# %%
X = np.array(raw_data.drop("user_action",axis=1))
Y = np.array(raw_data[["user_action"]])

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.5, shuffle=True)

# %%
X_train.shape
# Out:
# (5, 3)

# %%
model = Sequential()
model.add(Dense(HIDDEN_LAYER_SIZE, input_shape=(3,), activation="sigmoid"))
model.add(Dense(1, activation="sigmoid"))

# %%
model.compile(loss="mean_squared_error", optimizer="sgd", metrics=["accuracy"])

# %%
model.fit(X_train, Y_train, epochs=150, batch_size=2, verbose=1)
# Out:
# Epoch 1/150
# 3/3 [==============================] - 1s 2ms/step - loss: 0.2565 - accuracy: 0.6000
# Epoch 2/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2528 - accuracy: 0.6000
# Epoch 3/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2534 - accuracy: 0.6000
# Epoch 4/150
# 3/3 [==============================] - 0s 998us/step - loss: 0.2537 - accuracy: 0.6000
# Epoch 5/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2492 - accuracy: 0.6000
# Epoch 6/150
# 3/3 [==============================] - 0s 5ms/step - loss: 0.2524 - accuracy: 0.6000
# Epoch 7/150
# 3/3 [==============================] - 0s 4ms/step - loss: 0.2489 - accuracy: 0.6000
# Epoch 8/150
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2467 - accuracy: 0.6000
# Epoch 9/150
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2449 - accuracy: 0.6000
# Epoch 10/150
# ...

# %%
metrics = model.evaluate(X_test, Y_test, verbose=1)
print("%s: %.2f%%" % (model.metrics_names[1], metrics[1]*100))
# Out:
# 1/1 [==============================] - 0s 148ms/step - loss: 0.2682 - accuracy: 0.4000
# accuracy: 40.00%

# %%
results = model.predict(X_test)
print(results)
# Out:
# [[0.39012071]
#  [0.39054793]
#  [0.38657036]
#  [0.43638006]
#  [0.40878284]]
